# %% [markdown]
# # Interaction network construction

# %%
# Import dependencies for the complete notebook

import os
import config
from lib.networks import get_interactomes
from pathlib import Path
from config import METHODS, NETWORKS_PATH, DATA_REACTOME_PATH
from config import LEVELS
from lib.networks import get_json_filename, create_pathway_interaction_network, read_graph, \
    get_pathways_with_multiple_proteoforms, create_pathway_interaction_networks

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# Set the working directory to the root("/") of the repository
config.set_root_wd()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Initial working directory: C:\Users\luisp\OneDrive\Documents\phd\ProteoformNetworks\src\Python
# New working directory: c:\Users\luisp\OneDrive\Documents\phd\ProteoformNetworks

# %%
# Create interactome networks and store them in the /networks/interactomes/ directory
interactome_networks_path = config.NETWORKS_PATH + "interactomes/"
if not Path(interactome_networks_path).exists():
    os.mkdir(interactome_networks_path)
interactomes_no_sm, interactomes_with_sm, interactomes_with_unique_sm = get_interactomes(config.DATA_REACTOME_PATH, interactome_networks_path)
interactomes = [*interactomes_no_sm.values(), *interactomes_with_sm.values(), *interactomes_with_unique_sm.values()]

# %%
# Select list of pathways with proteoforms
pathway_networks_path = NETWORKS_PATH + "pathways/"
if not Path(pathway_networks_path).exists():
    os.mkdir(pathway_networks_path)
if not Path(pathway_networks_path + "complexes/").exists():
    os.mkdir(pathway_networks_path + "complexes/")
pathways_with_proteoforms = get_pathways_with_multiple_proteoforms(DATA_REACTOME_PATH, pathway_networks_path)
print(f"Selected {len(pathways_with_proteoforms)} pathways.")
pathways_with_proteoforms[1:5]
# Out:
# Selected 1468 pathways.
# ['R-HSA-1632852', 'R-HSA-5205685', 'R-HSA-8934903', 'R-HSA-9613354']

# %%
# Create interaction network for each pathway that has proteoforms with PTMs
# pathways_with_proteoforms = ["R-HSA-9013508"]
for pathway in pathways_with_proteoforms:
    create_pathway_interaction_networks(pathway, pathway_networks_path, True)
# Out:
# -- Creating interaction networks for pathway R-HSA-9613829
# -- Creating interaction networks for pathway R-HSA-1632852
# -- Creating interaction networks for pathway R-HSA-5205685
# -- Creating interaction networks for pathway R-HSA-8934903
# -- Creating interaction networks for pathway R-HSA-9613354
# -- Creating interaction networks for pathway R-HSA-9664873
# -- Creating interaction networks for pathway R-HSA-9646399
# -- Creating interaction networks for pathway R-HSA-9615710
# -- Creating interaction networks for pathway R-HSA-141444
# -- Creating interaction networks for pathway R-HSA-141405
# -- Creating interaction networks for pathway R-HSA-141430
# -- Creating interaction networks for pathway R-HSA-69481
# -- Creating interaction networks for pathway R-HSA-69473
# -- Creating interaction networks for pathway R-HSA-75035
# -- Creating interaction networks for pathway R-HSA-69478
# -- Creating interaction networks for pathway R-HSA-176187
# -- Creating interaction networks for pathway R-HSA-68911
# -- Creating interaction networks for pathway R-HSA-2468052
# -- Creating interaction networks for pathway R-HSA-69091
# -- Creating interaction networks for pathway R-HSA-69183
# -- Creating interaction networks for pathway R-HSA-69166
# -- Creating interaction networks for pathway R-HSA-69202
# -- Creating interaction networks for pathway R-HSA-69200
# -- Creating interaction networks for pathway R-HSA-187577
# -- Creating interaction networks for pathway R-HSA-68962
# -- Creating interaction networks for pathway R-HSA-68867
# -- Creating interaction networks for pathway R-HSA-68689
# -- Creating interaction networks for pathway R-HSA-68616
# -- Creating interaction networks for pathway R-HSA-1538133
# -- Creating interaction networks for pathway R-HSA-1362277
# -- Creating interaction networks for pathway R-HSA-1362300
# -- Creating interaction networks for pathway R-HSA-69231
# -- Creating interaction networks for pathway R-HSA-9754119
# -- Creating interaction networks for pathway R-HSA-2173795
# -- Creating interaction networks for pathway R-HSA-2173796
# -- Creating interaction networks for pathway R-HSA-2173789
# -- Creating interaction networks for pathway R-HSA-2173788
# -- Creating interaction networks for pathway R-HSA-2173791
# -- Creating interaction networks for pathway R-HSA-8849474
# -- Creating interaction networks for pathway R-HSA-8857538
# -- Creating interaction networks for pathway R-HSA-8849473
# -- Creating interaction networks for pathway R-HSA-8849472
# -- Creating interaction networks for pathway R-HSA-8849471
# -- Creating interaction networks for pathway R-HSA-8849470
# -- Creating interaction networks for pathway R-HSA-8849469
# -- Creating interaction networks for pathway R-HSA-8849468
# -- Creating interaction networks for pathway R-HSA-8847993
# -- Creating interaction networks for pathway R-HSA-1227986
# -- Creating interaction networks for pathway R-HSA-1963640
# -- Creating interaction networks for pathway R-HSA-1250196
# -- Creating interaction networks for pathway R-HSA-1963642
# -- Creating interaction networks for pathway R-HSA-9652282
# -- Creating interaction networks for pathway R-HSA-1251932
# -- Creating interaction networks for pathway R-HSA-8863795
# -- Creating interaction networks for pathway R-HSA-1358803
# -- Creating interaction networks for pathway R-HSA-1306955
# -- Creating interaction networks for pathway R-HSA-6785631
# -- Creating interaction networks for pathway R-HSA-5663220
# -- Creating interaction networks for pathway R-HSA-216083
# -- Creating interaction networks for pathway R-HSA-4086398
# -- Creating interaction networks for pathway R-HSA-4086400
# -- Creating interaction networks for pathway R-HSA-4608870
# -- Creating interaction networks for pathway R-HSA-5140745
# -- Creating interaction networks for pathway R-HSA-5099900
# -- Creating interaction networks for pathway R-HSA-201681
# -- Creating interaction networks for pathway R-HSA-3769402
# -- Creating interaction networks for pathway R-HSA-5368598
# -- Creating interaction networks for pathway R-HSA-4641262
# -- Creating interaction networks for pathway R-HSA-4641263
# -- Creating interaction networks for pathway R-HSA-4641258
# -- Creating interaction networks for pathway R-HSA-4641257
# -- Creating interaction networks for pathway R-HSA-3772470
# -- Creating interaction networks for pathway R-HSA-201722
# -- Creating interaction networks for pathway R-HSA-4411364
# -- Creating interaction networks for pathway R-HSA-201688
# -- Creating interaction networks for pathway R-HSA-195253
# -- Creating interaction networks for pathway R-HSA-196299
# -- Creating interaction networks for pathway R-HSA-4641265
# -- Creating interaction networks for pathway R-HSA-3238698
# -- Creating interaction networks for pathway R-HSA-418990
# -- Creating interaction networks for pathway R-HSA-420029
# -- Creating interaction networks for pathway R-HSA-446353
# -- Creating interaction networks for pathway R-HSA-446343
# -- Creating interaction networks for pathway R-HSA-446388
# -- Creating interaction networks for pathway R-HSA-446107
# -- Creating interaction networks for pathway R-HSA-1489509
# -- Creating interaction networks for pathway R-HSA-111997
# -- Creating interaction networks for pathway R-HSA-111933
# -- Creating interaction networks for pathway R-HSA-111957
# -- Creating interaction networks for pathway R-HSA-111931
# -- Creating interaction networks for pathway R-HSA-163615
# -- Creating interaction networks for pathway R-HSA-111932
# -- Creating interaction networks for pathway R-HSA-1257604
# -- Creating interaction networks for pathway R-HSA-198693
# -- Creating interaction networks for pathway R-HSA-198323
# -- Creating interaction networks for pathway R-HSA-199418
# -- Creating interaction networks for pathway R-HSA-6811558
# -- Creating interaction networks for pathway R-HSA-8943723
# -- Creating interaction networks for pathway R-HSA-8948747
# -- Creating interaction networks for pathway R-HSA-8943724
# -- Creating interaction networks for pathway R-HSA-8948751
# -- Creating interaction networks for pathway R-HSA-186763
# -- Creating interaction networks for pathway R-HSA-9648002
# -- Creating interaction networks for pathway R-HSA-5673001
# -- Creating interaction networks for pathway R-HSA-5674135
# -- Creating interaction networks for pathway R-HSA-5675221
# -- Creating interaction networks for pathway R-HSA-5674499
# -- Creating interaction networks for pathway R-HSA-5658442
# -- Creating interaction networks for pathway R-HSA-5673000
# -- Creating interaction networks for pathway R-HSA-1433557
# -- Creating interaction networks for pathway R-HSA-1433559
# -- Creating interaction networks for pathway R-HSA-209543
# -- Creating interaction networks for pathway R-HSA-209560
# -- Creating interaction networks for pathway R-HSA-193692
# -- Creating interaction networks for pathway R-HSA-193648
# -- Creating interaction networks for pathway R-HSA-205043
# -- Creating interaction networks for pathway R-HSA-198765
# -- Creating interaction networks for pathway R-HSA-198203
# -- Creating interaction networks for pathway R-HSA-177504
# -- Creating interaction networks for pathway R-HSA-171007
# -- Creating interaction networks for pathway R-HSA-167044
# -- Creating interaction networks for pathway R-HSA-170984
# -- Creating interaction networks for pathway R-HSA-170968
# -- Creating interaction networks for pathway R-HSA-187706
# -- Creating interaction networks for pathway R-HSA-187042
# -- Creating interaction networks for pathway R-HSA-187024
# -- Creating interaction networks for pathway R-HSA-193670
# -- Creating interaction networks for pathway R-HSA-198753
# -- Creating interaction networks for pathway R-HSA-202670
# -- Creating interaction networks for pathway R-HSA-199920
# -- Creating interaction networks for pathway R-HSA-9031628
# -- Creating interaction networks for pathway R-HSA-9619665
# -- Creating interaction networks for pathway R-HSA-198745
# -- Creating interaction networks for pathway R-HSA-167021
# -- Creating interaction networks for pathway R-HSA-113501
# -- Creating interaction networks for pathway R-HSA-113507
# -- Creating interaction networks for pathway R-HSA-2559584
# -- Creating interaction networks for pathway R-HSA-69017
# -- Creating interaction networks for pathway R-HSA-69601
# -- Creating interaction networks for pathway R-HSA-69895
# -- Creating interaction networks for pathway R-HSA-349425
# -- Creating interaction networks for pathway R-HSA-69541
# -- Creating interaction networks for pathway R-HSA-69563
# -- Creating interaction networks for pathway R-HSA-69656
# -- Creating interaction networks for pathway R-HSA-75815
# -- Creating interaction networks for pathway R-HSA-68949
# -- Creating interaction networks for pathway R-HSA-5693548
# -- Creating interaction networks for pathway R-HSA-5693565
# -- Creating interaction networks for pathway R-HSA-5693568
# -- Creating interaction networks for pathway R-HSA-5693554
# -- Creating interaction networks for pathway R-HSA-5693616
# -- Creating interaction networks for pathway R-HSA-5693579
# -- Creating interaction networks for pathway R-HSA-5693607
# -- Creating interaction networks for pathway R-HSA-5685942
# -- Creating interaction networks for pathway R-HSA-5685938
# -- Creating interaction networks for pathway R-HSA-5693571
# -- Creating interaction networks for pathway R-HSA-5685939
# -- Creating interaction networks for pathway R-HSA-75108
# -- Creating interaction networks for pathway R-HSA-114294
# -- Creating interaction networks for pathway R-HSA-111452
# -- Creating interaction networks for pathway R-HSA-111463
# -- Creating interaction networks for pathway R-HSA-111464
# -- Creating interaction networks for pathway R-HSA-111469
# -- Creating interaction networks for pathway R-HSA-111457
# -- Creating interaction networks for pathway R-HSA-9627069
# -- Creating interaction networks for pathway R-HSA-111458
# -- Creating interaction networks for pathway R-HSA-111459
# -- Creating interaction networks for pathway R-HSA-111447
# -- Creating interaction networks for pathway R-HSA-111448
# -- Creating interaction networks for pathway R-HSA-111446
# -- Creating interaction networks for pathway R-HSA-139910
# -- Creating interaction networks for pathway R-HSA-139915
# -- Creating interaction networks for pathway R-HSA-9014843
# -- Creating interaction networks for pathway R-HSA-5684264
# -- Creating interaction networks for pathway R-HSA-445989
# -- Creating interaction networks for pathway R-HSA-9020702
# -- Creating interaction networks for pathway R-HSA-448706
# -- Creating interaction networks for pathway R-HSA-5620971
# -- Creating interaction networks for pathway R-HSA-111453
# -- Creating interaction networks for pathway R-HSA-2562578
# -- Creating interaction networks for pathway R-HSA-936964
# -- Creating interaction networks for pathway R-HSA-937072
# -- Creating interaction networks for pathway R-HSA-450321
# -- Creating interaction networks for pathway R-HSA-450341
# -- Creating interaction networks for pathway R-HSA-450302
# -- Creating interaction networks for pathway R-HSA-110056
# -- Creating interaction networks for pathway R-HSA-112411
# -- Creating interaction networks for pathway R-HSA-112409
# -- Creating interaction networks for pathway R-HSA-937041
# -- Creating interaction networks for pathway R-HSA-5218900
# -- Creating interaction networks for pathway R-HSA-5675482
# -- Creating interaction networks for pathway R-HSA-211728
# -- Creating interaction networks for pathway R-HSA-211733
# -- Creating interaction networks for pathway R-HSA-418889
# -- Creating interaction networks for pathway R-HSA-3371378
# -- Creating interaction networks for pathway R-HSA-69416
# -- Creating interaction networks for pathway R-HSA-75158
# -- Creating interaction networks for pathway R-HSA-140534
# -- Creating interaction networks for pathway R-HSA-166166
# -- Creating interaction networks for pathway R-HSA-5213460
# -- Creating interaction networks for pathway R-HSA-9686347
# -- Creating interaction networks for pathway R-HSA-140342
# -- Creating interaction networks for pathway R-HSA-111465
# -- Creating interaction networks for pathway R-HSA-264870
# -- Creating interaction networks for pathway R-HSA-351906
# -- Creating interaction networks for pathway R-HSA-352238
# -- Creating interaction networks for pathway R-HSA-211736
# -- Creating interaction networks for pathway R-HSA-75893
# -- Creating interaction networks for pathway R-HSA-5357905
# -- Creating interaction networks for pathway R-HSA-5357956
# -- Creating interaction networks for pathway R-HSA-5357786
# -- Creating interaction networks for pathway R-HSA-9007892
# -- Creating interaction networks for pathway R-HSA-9008059
# -- Creating interaction networks for pathway R-HSA-9012546
# -- Creating interaction networks for pathway R-HSA-166058
# -- Creating interaction networks for pathway R-HSA-937039
# -- Creating interaction networks for pathway R-HSA-937042
# -- Creating interaction networks for pathway R-HSA-5686938
# -- Creating interaction networks for pathway R-HSA-1251985
# -- Creating interaction networks for pathway R-HSA-1253288
# -- Creating interaction networks for pathway R-HSA-1250347
# -- Creating interaction networks for pathway R-HSA-1250342
# -- Creating interaction networks for pathway R-HSA-8939902
# -- Creating interaction networks for pathway R-HSA-8940973
# -- Creating interaction networks for pathway R-HSA-8941326
# -- Creating interaction networks for pathway R-HSA-8941284
# -- Creating interaction networks for pathway R-HSA-5610785
# -- Creating interaction networks for pathway R-HSA-5610780
# -- Creating interaction networks for pathway R-HSA-5610787
# -- Creating interaction networks for pathway R-HSA-5610783
# -- Creating interaction networks for pathway R-HSA-8934593
# -- Creating interaction networks for pathway R-HSA-8939256
# -- Creating interaction networks for pathway R-HSA-8939242
# -- Creating interaction networks for pathway R-HSA-8936459
# -- Creating interaction networks for pathway R-HSA-8939247
# -- Creating interaction networks for pathway R-HSA-8931987
# -- Creating interaction networks for pathway R-HSA-8939246
# -- Creating interaction networks for pathway R-HSA-8939243
# -- Creating interaction networks for pathway R-HSA-8939236
# -- Creating interaction networks for pathway R-HSA-8877330
# -- Creating interaction networks for pathway R-HSA-8939245
# -- Creating interaction networks for pathway R-HSA-2122948
# -- Creating interaction networks for pathway R-HSA-1912408
# -- Creating interaction networks for pathway R-HSA-1912420
# -- Creating interaction networks for pathway R-HSA-9017802
# -- Creating interaction networks for pathway R-HSA-9013507
# -- Creating interaction networks for pathway R-HSA-9013508
# -- Creating interaction networks for pathway R-HSA-9013700
# -- Creating interaction networks for pathway R-HSA-9604323
# -- Creating interaction networks for pathway R-HSA-9013695
# -- Creating interaction networks for pathway R-HSA-1912399
# -- Creating interaction networks for pathway R-HSA-2122947
# -- Creating interaction networks for pathway R-HSA-6804757
# -- Creating interaction networks for pathway R-HSA-6804754
# -- Creating interaction networks for pathway R-HSA-2428933
# -- Creating interaction networks for pathway R-HSA-165158
# -- Creating interaction networks for pathway R-HSA-165160
# -- Creating interaction networks for pathway R-HSA-449836
# -- Creating interaction networks for pathway R-HSA-109704
# -- Creating interaction networks for pathway R-HSA-112399
# -- Creating interaction networks for pathway R-HSA-112412
# -- Creating interaction networks for pathway R-HSA-2428928
# -- Creating interaction networks for pathway R-HSA-166208
# -- Creating interaction networks for pathway R-HSA-380972
# -- Creating interaction networks for pathway R-HSA-165159
# -- Creating interaction networks for pathway R-HSA-165181
# -- Creating interaction networks for pathway R-HSA-2404192
# -- Creating interaction networks for pathway R-HSA-5654700
# -- Creating interaction networks for pathway R-HSA-5654699
# -- Creating interaction networks for pathway R-HSA-5654221
# -- Creating interaction networks for pathway R-HSA-5654695
# -- Creating interaction networks for pathway R-HSA-1295596
# -- Creating interaction networks for pathway R-HSA-5654727
# -- Creating interaction networks for pathway R-HSA-6803529
# -- Creating interaction networks for pathway R-HSA-190375
# -- Creating interaction networks for pathway R-HSA-190377
# -- Creating interaction networks for pathway R-HSA-190372
# -- Creating interaction networks for pathway R-HSA-190371
# -- Creating interaction networks for pathway R-HSA-5654732
# -- Creating interaction networks for pathway R-HSA-5654704
# -- Creating interaction networks for pathway R-HSA-5654706
# -- Creating interaction networks for pathway R-HSA-5654227
# -- Creating interaction networks for pathway R-HSA-5654710
# -- Creating interaction networks for pathway R-HSA-9034013
# -- Creating interaction networks for pathway R-HSA-9603381
# -- Creating interaction networks for pathway R-HSA-9034793
# -- Creating interaction networks for pathway R-HSA-6794361
# -- Creating interaction networks for pathway R-HSA-388844
# -- Creating interaction networks for pathway R-HSA-8849932
# -- Creating interaction networks for pathway R-HSA-9034015
# -- Creating interaction networks for pathway R-HSA-9603505
# -- Creating interaction networks for pathway R-HSA-9034864
# -- Creating interaction networks for pathway R-HSA-212718
# -- Creating interaction networks for pathway R-HSA-179812
# -- Creating interaction networks for pathway R-HSA-180336
# -- Creating interaction networks for pathway R-HSA-180292
# -- Creating interaction networks for pathway R-HSA-182971
# -- Creating interaction networks for pathway R-HSA-5626467
# -- Creating interaction networks for pathway R-HSA-399955
# -- Creating interaction networks for pathway R-HSA-416572
# -- Creating interaction networks for pathway R-HSA-416550
# -- Creating interaction networks for pathway R-HSA-399954
# -- Creating interaction networks for pathway R-HSA-416700
# -- Creating interaction networks for pathway R-HSA-399956
#     * Creating network networks\pathways\R-HSA-399956_genes_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-399956_proteins_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-399956_proteoforms_with_unique_sm.json
# -- Creating interaction networks for pathway R-HSA-6804115
#     * Creating network networks\pathways\R-HSA-6804115_genes_no_sm.json
#     * Creating network networks\pathways\R-HSA-6804115_proteins_no_sm.json
#     * Creating network networks\pathways\R-HSA-6804115_proteoforms_no_sm.json
#     * Creating network networks\pathways\R-HSA-6804115_genes_with_sm.json
#     * Creating network networks\pathways\R-HSA-6804115_proteins_with_sm.json
#     * Creating network networks\pathways\R-HSA-6804115_proteoforms_with_sm.json
#     * Creating network networks\pathways\R-HSA-6804115_genes_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-6804115_proteins_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-6804115_proteoforms_with_unique_sm.json
# -- Creating interaction networks for pathway R-HSA-6804116
#     * Creating network networks\pathways\R-HSA-6804116_genes_no_sm.json
#     * Creating network networks\pathways\R-HSA-6804116_proteins_no_sm.json
#     * Creating network networks\pathways\R-HSA-6804116_proteoforms_no_sm.json
#     * Creating network networks\pathways\R-HSA-6804116_genes_with_sm.json
#     * Creating network networks\pathways\R-HSA-6804116_proteins_with_sm.json
#     * Creating network networks\pathways\R-HSA-6804116_proteoforms_with_sm.json
#     * Creating network networks\pathways\R-HSA-6804116_genes_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-6804116_proteins_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-6804116_proteoforms_with_unique_sm.json
# -- Creating interaction networks for pathway R-HSA-6804114
#     * Creating network networks\pathways\R-HSA-6804114_genes_no_sm.json
#     * Creating network networks\pathways\R-HSA-6804114_proteins_no_sm.json
#     * Creating network networks\pathways\R-HSA-6804114_proteoforms_no_sm.json
#     * Creating network networks\pathways\R-HSA-6804114_genes_with_sm.json
#     * Creating network networks\pathways\R-HSA-6804114_proteins_with_sm.json
#     * Creating network networks\pathways\R-HSA-6804114_proteoforms_with_sm.json
#     * Creating network networks\pathways\R-HSA-6804114_genes_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-6804114_proteins_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-6804114_proteoforms_with_unique_sm.json
# -- Creating interaction networks for pathway R-HSA-2565942
#     * Creating network networks\pathways\R-HSA-2565942_genes_no_sm.json
#     * Creating network networks\pathways\R-HSA-2565942_proteins_no_sm.json
#     * Creating network networks\pathways\R-HSA-2565942_proteoforms_no_sm.json
#     * Creating network networks\pathways\R-HSA-2565942_genes_with_sm.json
#     * Creating network networks\pathways\R-HSA-2565942_proteins_with_sm.json
#     * Creating network networks\pathways\R-HSA-2565942_proteoforms_with_sm.json
#     * Creating network networks\pathways\R-HSA-2565942_genes_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-2565942_proteins_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-2565942_proteoforms_with_unique_sm.json
# -- Creating interaction networks for pathway R-HSA-69273
#     * Creating network networks\pathways\R-HSA-69273_genes_no_sm.json
#     * Creating network networks\pathways\R-HSA-69273_proteins_no_sm.json
#     * Creating network networks\pathways\R-HSA-69273_proteoforms_no_sm.json
#     * Creating network networks\pathways\R-HSA-69273_genes_with_sm.json
#     * Creating network networks\pathways\R-HSA-69273_proteins_with_sm.json
#     * Creating network networks\pathways\R-HSA-69273_proteoforms_with_sm.json
#     * Creating network networks\pathways\R-HSA-69273_genes_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-69273_proteins_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-69273_proteoforms_with_unique_sm.json
# -- Creating interaction networks for pathway R-HSA-170145
#     * Creating network networks\pathways\R-HSA-170145_genes_no_sm.json
#     * Creating network networks\pathways\R-HSA-170145_proteins_no_sm.json
#     * Creating network networks\pathways\R-HSA-170145_proteoforms_no_sm.json
#     * Creating network networks\pathways\R-HSA-170145_genes_with_sm.json
#     * Creating network networks\pathways\R-HSA-170145_proteins_with_sm.json
#     * Creating network networks\pathways\R-HSA-170145_proteoforms_with_sm.json
#     * Creating network networks\pathways\R-HSA-170145_genes_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-170145_proteins_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-170145_proteoforms_with_unique_sm.json
# -- Creating interaction networks for pathway R-HSA-8854521
#     * Creating network networks\pathways\R-HSA-8854521_genes_no_sm.json
#     * Creating network networks\pathways\R-HSA-8854521_proteins_no_sm.json
#     * Creating network networks\pathways\R-HSA-8854521_proteoforms_no_sm.json
#     * Creating network networks\pathways\R-HSA-8854521_genes_with_sm.json
#     * Creating network networks\pathways\R-HSA-8854521_proteins_with_sm.json
#     * Creating network networks\pathways\R-HSA-8854521_proteoforms_with_sm.json
#     * Creating network networks\pathways\R-HSA-8854521_genes_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-8854521_proteins_with_unique_sm.json
#     * Creating network networks\pathways\R-HSA-8854521_proteoforms_with_unique_sm.json
# -- Creating interaction networks for pathway R-HSA-156711
#     * Creating network networks\pathways\R-HSA-156711_genes_no_sm.json
#     * Creating network networks\pathways\R-HSA-156711_proteins_no_sm.json
#     * Creating network networks\pathways\R-HSA-156711_proteoforms_no_sm.json
#     * Creating network networks\pathways\R-HSA-156711_genes_with_sm.json
#     * Creating network networks\pathways\R-HSA-156711_proteins_with_sm.json
#     * Creating network networks\pathways\R-HSA-156711_proteoforms_with_sm.json
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\luisp\OneDrive\Documents\phd\ProteoformNetworks\src\Python\1_network_construction.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/1_network_construction.ipynb#ch0000004?line=0'>1</a> # Create interaction network for each pathway that has proteoforms with PTMs
#       <a href='vscode-notebook-cell:/c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/1_network_construction.ipynb#ch0000004?line=1'>2</a> # pathways_with_proteoforms = ["R-HSA-9013508"]
#       <a href='vscode-notebook-cell:/c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/1_network_construction.ipynb#ch0000004?line=2'>3</a> for pathway in pathways_with_proteoforms:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/1_network_construction.ipynb#ch0000004?line=3'>4</a>     create_pathway_interaction_networks(pathway, pathway_networks_path, True)
#
# File c:\Users\luisp\OneDrive\Documents\phd\ProteoformNetworks\src\Python\lib\networks.py:124, in create_pathway_interaction_networks(pathway, out_path, v)
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=121'>122</a> for method in config.METHODS:
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=122'>123</a>     for level in config.LEVELS:
# --> <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=123'>124</a>         create_pathway_interaction_network(pathway, level, method, out_path, v)
#
# File c:\Users\luisp\OneDrive\Documents\phd\ProteoformNetworks\src\Python\lib\networks.py:82, in create_pathway_interaction_network(pathway, level, method, out_path, v)
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=78'>79</a>         print(f"    * Creating network {filename}")
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=79'>80</a>     participants = {level: get_participants_by_pathway(
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=80'>81</a>         pathway, level, out_path) for level in [level, sm]}
# ---> <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=81'>82</a>     components = {level: get_components_by_pathway(
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=82'>83</a>         pathway, level, out_path) for level in [level, sm]}
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=83'>84</a>     create_interaction_network(
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=84'>85</a>         level, method, participants, components, out_path, pathway, False)
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=85'>86</a> # else:
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=86'>87</a> #     print(f"    * Network {filename} already exists..")
#
# File c:\Users\luisp\OneDrive\Documents\phd\ProteoformNetworks\src\Python\lib\networks.py:82, in <dictcomp>(.0)
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=78'>79</a>         print(f"    * Creating network {filename}")
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=79'>80</a>     participants = {level: get_participants_by_pathway(
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=80'>81</a>         pathway, level, out_path) for level in [level, sm]}
# ---> <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=81'>82</a>     components = {level: get_components_by_pathway(
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=82'>83</a>         pathway, level, out_path) for level in [level, sm]}
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=83'>84</a>     create_interaction_network(
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=84'>85</a>         level, method, participants, components, out_path, pathway, False)
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=85'>86</a> # else:
#      <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/networks.py?line=86'>87</a> #     print(f"    * Network {filename} already exists..")
#
# File c:\Users\luisp\OneDrive\Documents\phd\ProteoformNetworks\src\Python\lib\graph_database_access.py:199, in get_components_by_pathway(pathway, level, out_path)
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=194'>195</a> df_complexes = get_complexes_by_pathway(pathway)
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=196'>197</a> if len(df_complexes) > 0:
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=197'>198</a>     # Get the components of each complex
# --> <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=198'>199</a>     dfs_components = [get_complex_components_by_complex(complex, level, out_path) for complex in
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=199'>200</a>                       df_complexes["Complex"]]
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=200'>201</a>     components = pd.concat(dfs_components)
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=201'>202</a>     return components
#
# File c:\Users\luisp\OneDrive\Documents\phd\ProteoformNetworks\src\Python\lib\graph_database_access.py:199, in <listcomp>(.0)
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=194'>195</a> df_complexes = get_complexes_by_pathway(pathway)
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=196'>197</a> if len(df_complexes) > 0:
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=197'>198</a>     # Get the components of each complex
# --> <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=198'>199</a>     dfs_components = [get_complex_components_by_complex(complex, level, out_path) for complex in
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=199'>200</a>                       df_complexes["Complex"]]
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=200'>201</a>     components = pd.concat(dfs_components)
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=201'>202</a>     return components
#
# File c:\Users\luisp\OneDrive\Documents\phd\ProteoformNetworks\src\Python\lib\graph_database_access.py:278, in get_complex_components_by_complex(complex, level, out_path)
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=275'>276</a> if len(components) == 0:
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=276'>277</a>     components = get_empty_components_dataframe(level)
# --> <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=277'>278</a> components.to_csv(filename)
#     <a href='file:///c%3A/Users/luisp/OneDrive/Documents/phd/ProteoformNetworks/src/Python/lib/graph_database_access.py?line=278'>279</a> return components
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:3563, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3551'>3552</a> df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3553'>3554</a> formatter = DataFrameFormatter(
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3554'>3555</a>     frame=df,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3555'>3556</a>     header=header,
#    (...)
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3559'>3560</a>     decimal=decimal,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3560'>3561</a> )
# -> <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3562'>3563</a> return DataFrameRenderer(formatter).to_csv(
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3563'>3564</a>     path_or_buf,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3564'>3565</a>     line_terminator=line_terminator,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3565'>3566</a>     sep=sep,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3566'>3567</a>     encoding=encoding,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3567'>3568</a>     errors=errors,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3568'>3569</a>     compression=compression,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3569'>3570</a>     quoting=quoting,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3570'>3571</a>     columns=columns,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3571'>3572</a>     index_label=index_label,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3572'>3573</a>     mode=mode,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3573'>3574</a>     chunksize=chunksize,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3574'>3575</a>     quotechar=quotechar,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3575'>3576</a>     date_format=date_format,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3576'>3577</a>     doublequote=doublequote,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3577'>3578</a>     escapechar=escapechar,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3578'>3579</a>     storage_options=storage_options,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/generic.py?line=3579'>3580</a> )
#
# File C:\Python310\lib\site-packages\pandas\io\formats\format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/format.py?line=1158'>1159</a>     created_buffer = False
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/format.py?line=1160'>1161</a> csv_formatter = CSVFormatter(
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/format.py?line=1161'>1162</a>     path_or_buf=path_or_buf,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/format.py?line=1162'>1163</a>     line_terminator=line_terminator,
#    (...)
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/format.py?line=1177'>1178</a>     formatter=self.fmt,
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/format.py?line=1178'>1179</a> )
# -> <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/format.py?line=1179'>1180</a> csv_formatter.save()
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/format.py?line=1181'>1182</a> if created_buffer:
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/format.py?line=1182'>1183</a>     assert isinstance(path_or_buf, StringIO)
#
# File C:\Python310\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=236'>237</a> """
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=237'>238</a> Create the writer & save.
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=238'>239</a> """
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=239'>240</a> # apply compression and byte/text conversion
# --> <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=240'>241</a> with get_handle(
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=241'>242</a>     self.filepath_or_buffer,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=242'>243</a>     self.mode,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=243'>244</a>     encoding=self.encoding,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=244'>245</a>     errors=self.errors,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=245'>246</a>     compression=self.compression,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=246'>247</a>     storage_options=self.storage_options,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=247'>248</a> ) as handles:
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=248'>249</a>
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=249'>250</a>     # Note: self.encoding is irrelevant here
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=250'>251</a>     self.writer = csvlib.writer(
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=251'>252</a>         handles.handle,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=252'>253</a>         lineterminator=self.line_terminator,
#    (...)
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=257'>258</a>         quotechar=self.quotechar,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=258'>259</a>     )
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/formats/csvs.py?line=260'>261</a>     self._save()
#
# File C:\Python310\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=783'>784</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=784'>785</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=785'>786</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=786'>787</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=787'>788</a>         # Encoding
# --> <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=788'>789</a>         handle = open(
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=789'>790</a>             handle,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=790'>791</a>             ioargs.mode,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=791'>792</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=792'>793</a>             errors=errors,
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=793'>794</a>             newline="",
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=794'>795</a>         )
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=795'>796</a>     else:
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=796'>797</a>         # Binary mode
#     <a href='file:///c%3A/Python310/lib/site-packages/pandas/io/common.py?line=797'>798</a>         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'networks/pathways/complexes/complex_R-HSA-4088300_sm.csv'

# %% [markdown]
# # Create module networks
#
# #### Gather data
#
# - Set of entities associated to the disease: PhegenI contains disease associated genes
# - Set of interactions among entities: Implicit interactions in Reactome pathways
#
# #### Make sure data is there
# #### Read traits
# #### Create gene network for a trait
#
# Input:
# - Gene interactome
# - Set of entities associated to the disease
#
# Process A:
# - Induce subnetwork from interactome
# Process B:
# - Query Neo4j for Reactions where two proteins of the set are participating
#
# #### Create protein network for a trait
#
# Given a single gene can result in multiple product proteins due to alternative splicing.
#
# * Check if there are cases where the products of a single gene are annotated to a different set of reactions.
#
# Same as process for gene networks plus additional steps:
#  - Remove the
#  -
#
# #### Create proteoform network for a trait
